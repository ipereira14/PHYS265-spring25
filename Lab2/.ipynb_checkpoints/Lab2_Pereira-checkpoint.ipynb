# %% [markdown]
# # Lab 2: Mine Crafting

# %% [markdown]
# # Part 1: The Ideal Case

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp

# %%
# Quantities
G = 6.6743E-11 # m^3/kg/s^2
g = 9.81 # Acceleration due to gravity
massEarth = 5.972E24 # kg
massMoon = 7.35E22 # kg
radiusEarth = 6378.1* 10**3 # km
radiusMoon = 1738.1 # km
earthRotationalRateEquator = 7.272E5 # 1/s
alpha = 0
gamma = 2
    
# radians per second

# Number 1: Time to reach the bottom of a 4km shaft
# alpha is 0 in part 1 since there is no drag
# maybe use a different equation????
y0 = 4000 # m
v0 = 0 # m/s
timeFall = np.sqrt((2 * y0) / g) # this is equation 1
print(timeFall) # seconds

# Number 2: Reduce the equation into a system
def system(t, x):
    y, v = x  # unpack position and velocity
    dydt = v
    dvdt = -g - alpha * v**gamma
    return [dydt, dvdt]
x0 = [y0,v0]

# Number 3:
t_span = (0, 2 * timeFall) 
initialConditions = [y0, v0]
soln = solve_ivp(system, t_span, initialConditions, t_eval=np.linspace(0, 2 * timeFall, 1000), events=lambda t, Y: Y[0])

tVals = soln.t
yVals = soln.y[0]
vVals = soln.y[1]

fig, ax = plt.subplots()
ax.plot(tVals, yVals, label="Height", color="tab:red") 
ax.axhline(0, color="black", linestyle="--")  # Bottom of the shaft
ax.tick_params(axis="y", labelcolor="tab:red")#using tab to color code the labels
ax.set_xlabel("Time (s)")
ax.set_ylabel("Position (m)", color="tab:red")
ax1 = ax.twinx()
ax1.set_ylabel("Velocity (m/s)", color="tab:blue")
ax1.plot(tVals, vVals, label="Velocity", color="tab:blue")
ax1.tick_params(axis="y", labelcolor="tab:blue")
ax.set_title("Free Fall: Position and Velocity") # FIGURE 1
ax.grid()

# Number 4:
#solution for free-fall time
numerical = soln.t_events[0][0]
print(f"Numerical free-fall time: {numerical} seconds")
# Out:
# 28.55686245854129
# Numerical free-fall time: 28.556862458541282 seconds

# %% [markdown]
# # Part 2: Including Drag and a Variable g

# %%
# dont ignore drag

# Number 1
#variables
step = 0.1
totTime = 100
Nstep = int(totTime/step)
time = np.linspace(0, totTime, Nstep)
position = np.zeros(Nstep)
velocity = np.zeros(Nstep)

#IC
position[0] = radiusEarth # meters
velocity[0] = 0

# Integrating
for i in range(1, Nstep):
    r = position[i-1]
    gR = g * (r/radiusEarth)
    velocity[i] = velocity[i-1]+ (-gR) * step
    position[i] = position [i-1] + velocity[i] *step
    if position[i] <= 0:
        position[i] = 0
        break
heightFromBottom = (radiusEarth* 10**3) - position

# Figure 2
fig, ax = plt.subplots()
ax.plot(time, heightFromBottom, label= "Position", color ='red')
ax.plot(time, velocity, label = "Velocity", color = 'blue')
ax.set_xlabel("Time (s)")
ax.set_title("Position vs. Time")
ax.legend()
ax.grid()

# Number 2
# What effect does incorporating a height-dependent g have on the fall time? Explain
print("Incorporating a height-dependent g will affect the free fall since the graviational acceleration decreases as the distance from Earth increases. The free fall time will increase as the distance from Earth is greater.")

# Number 3: Incorporating drag
vTerminal = 50 # m/s

# How can you calibrate the value of alpha? Look at lecture 16. What affect does including drag have on the fall time?
# Out:
# Incorporating a height-dependent g will affect the free fall since the graviational acceleration decreases as the distance from Earth increases. The free fall time will increase as the distance from Earth is greater.

# %% [markdown]
# # Part 3: The Coriolis Force

# %%
# the coriolis force
# need to do a cross product
# Fcx = 0
# Number 1
omega = 1 # maybe make the earth's rotation
def g(y):
    return G * massEarth / radiusEarth**3

def coriolis(t, X):
    y, vy, x, vx = X
    dydt = vy
    dvydt = g(y)
    dxdt = vx
    dvxdt = 2 * omega * vy  # coriolis acceleration in x-direction
    return [dydt, dvydt, dxdt, dvxdt]

# Function so it stops when y=0, overheard that we needed this
def hitGround(t, X):
    return X[0]
hitGround.terminal = True
hitGround.direction = -1
y0 = 4000000
x0, vx0 = 0.0, 0.0
IC = np.array([y0,v0,x0,vx0])
t_span = (0, 300)  
soln = solve_ivp(coriolis, t_span, IC, t_eval=np.linspace(0, 300, 1000), events=hitGround)

if soln.t_events[0].size > 0:
    fallTime = soln.t_events[0][0]
    print(f"Numerical free-fall time with Coriolis force: {fallTime} seconds")
else:
    print("The object did not reach the ground within the simulation time.")
    
# Extract results
tVals = soln.t
yVals = soln.y[0] if soln.y.shape[1] > 0 else []
xVals = soln.y[2] if soln.y.shape[1] > 0 else []


# Number 2, assuming alpha = 0
# FIgure 3
fig, ax = plt.subplots()
ax.plot(yVals - radiusEarth, xVals, 'r.', markersize=2, label="Particle Path")
ax.set_xlabel("Depth (m)")
ax.set_ylabel("Transverse Position (m)")
ax.set_title("Transverse Position vs Depth")
ax.legend()
ax.grid()

# Number 3: If the mine shaft is 5m wide, does the test mass reach the bottom? Or does it bump into the wall first?
shaftWidth = 5  # meters
maxX = np.max(np.abs(xVals))
if maxX >= shaftWidth / 2:
    print("The test mass hits the shaft wall before reaching the bottom.")
else:
    print("The test mass reaches the bottom without hitting the wall.")

# Number 4: Does the drag make any difference here?
print("Drag does indeed make a difference")
# Out:
# The object did not reach the ground within the simulation time.
# The test mass hits the shaft wall before reaching the bottom.
# Drag does indeed make a difference

# %% [markdown]
# # Part 4: An infinitely deep mine

# %%
# NUmber 1
def motion(t, X):
    y, v = X
    dydt = v
    dvdt = g(y)
    return [dydt, dvdt]
yI = radiusEarth
IC = [yI, v0]

# SOlving
t_span = (0, 6000)
t_eval = np.linspace(t_span[0], t_span[1], 1000)
soln1 = solve_ivp(motion, t_span, IC, t_eval=t_eval, rtol=1e-8, atol=1e-10)
tVals = soln1.t
yVals = soln1.y[0]
vVals = soln1.y[1]

# plotting depth and velocity; Figure 4
fig, ax = plt.subplots(2, 1, figsize=(10,8)) # change the fig size

ax[0].plot(tVals, yVals, label="Depth y(t)", color='red')
ax[0].set_xlabel("Time (s)")
ax[0].set_ylabel("Depth (m)")
ax[0].set_title("Depth vs Time")
ax[0].grid()
fig.subplots_adjust(hspace=0.4) # Adds vertical space between the plots

ax[1].plot(tVals, vVals, label="Velocity v(t)", color='green')
ax[1].set_xlabel("Time (s)")
ax[1].set_ylabel("Velocity (m/s)")
ax[1].set_title("Velocity vs Time")
ax[1].grid()

# Number 2
centerCrossing = np.where(yVals <= 0)[0][0] if np.any(yVals <= 0) else None
if centerCrossing:
    # Need to find the time and the speed, ALSO AT WHAT TIME, make sure to include that
    tCenter = tVals[centerCrossing] # time at the center
    sCenter = abs(vVals[centerCrossing]) # speed at the center
    print(f"Time to reach Earth's center: {tCenter} s")
    print(f"Speed at center: {sCenter} m/s")

# Number 3, making an orbital comparision
tOrbit = 2 * np.pi * np.sqrt(radiusEarth**3 / (G * massEarth))
print(f"Orbital period: {tOrbit} s")
# Out:
# Orbital period: 5069.371199675785 s

# %% [markdown]
# # Part 5: A non-uniform Earth

# %% [markdown]
# # Part 6: A lunar mine shaft
