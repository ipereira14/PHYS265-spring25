# %%
# !pip install reservoirpy
# Out:
# Collecting reservoirpy
#   Downloading reservoirpy-0.3.13.post1-py3-none-any.whl.metadata (14 kB)
# Collecting dill>=0.3.1.1 (from reservoirpy)
#   Downloading dill-0.4.0-py3-none-any.whl.metadata (10 kB)
# Collecting joblib>=0.14.1 (from reservoirpy)
#   Downloading joblib-1.5.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: numpy>=1.21.1 in c:\users\bpere\appdata\roaming\jupyterlab-desktop\envs\env_2\lib\site-packages (from reservoirpy) (2.1.0)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\bpere\appdata\roaming\jupyterlab-desktop\envs\env_2\lib\site-packages (from reservoirpy) (1.15.2)
# Requirement already satisfied: tqdm>=4.43.0 in c:\users\bpere\appdata\roaming\jupyterlab-desktop\envs\env_2\lib\site-packages (from reservoirpy) (4.66.5)
# Requirement already satisfied: colorama in c:\users\bpere\appdata\roaming\jupyterlab-desktop\envs\env_2\lib\site-packages (from tqdm>=4.43.0->reservoirpy) (0.4.6)
# Downloading reservoirpy-0.3.13.post1-py3-none-any.whl (209 kB)
# Downloading dill-0.4.0-py3-none-any.whl (119 kB)
# Downloading joblib-1.5.0-py3-none-any.whl (307 kB)
# Installing collected packages: joblib, dill, reservoirpy
# Successfully installed dill-0.4.0 joblib-1.5.0 reservoirpy-0.3.13.post1

# %%
import numpy as np
import matplotlib.pyplot as plt
from reservoirpy.nodes import Reservoir, Ridge

# Generate sine wave data
T = 1000
t = np.linspace(0, 10*np.pi, T)
data = np.sin(t)

# Prepare training and testing datasets
input_data = data[:-1].reshape(-1, 1)
target_data = data[1:].reshape(-1, 1)

train_len = 800
x_train, y_train = input_data[:train_len], target_data[:train_len]
x_test, y_test = input_data[train_len:], target_data[train_len:]

# Define the Echo State Network
reservoir = Reservoir(units=200, lr=0.3, sr=0.9, input_scaling=0.5)
readout = Ridge(ridge=1e-6)

esn = reservoir >> readout

# Train the network
esn = esn.fit(x_train, y_train)

# Predict
y_pred = esn.run(x_test)

# Plot results
plt.figure(figsize=(10, 4))
plt.plot(y_test, label="True Signal")
plt.plot(y_pred, label="Predicted Signal", linestyle="--")
plt.legend()
plt.title("Sine Wave Prediction with ReservoirPy")
plt.show()
# Out:
# Running Model-0:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Model-0:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Model-0: 202it [00:00, 2002.60it/s]
# Running Model-0: 403it [00:00, 1580.74it/s]
# Running Model-0: 567it [00:00, 1538.01it/s]
# Running Model-0: 800it [00:00, 1506.81it/s]
# Running Model-0: 100%|██████████| 1/1 [00:00<00:00,  1.49it/s]
# Fitting node Ridge-0...
# Running Model-0: 199it [00:00, 3053.15it/s]

# %%
from reservoirpy.datasets import lorenz96
timeseries = lorenz96(1000, h=0.1, N=5)
timeseries.shape
# Out:
# (1000, 5)

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from reservoirpy.datasets import lorenz

# Loading the data
timeseries = lorenz(10000)
x, y, z = timeseries[:, 0], timeseries[:, 1], timeseries[:, 2]

# 3D plotting
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')
ax.plot(x, y, z, lw=0.1)
ax.set_title("Lorenz Attractor Model")
ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_zlabel("Z")
# Out:
# Text(0.5, 0, 'Z')

# %%
from reservoirpy.datasets import lorenz
from reservoirpy.nodes import Reservoir, Ridge
import numpy as np
import matplotlib.pyplot as plt

# Load Lorenz data
timeseries = lorenz(10000) # from example
data = timeseries[:, 0].reshape(-1, 1)

trainLen = 8000
xTrain = data[:trainLen]
yTrain = data[1:trainLen + 1]
xTest = data[trainLen:-1]
yTest = data[trainLen + 1:]

# Define ESN NO noise
reservoir = Reservoir(units=300, sr=1.25, lr=0.3, input_scaling=0.5)
readout = Ridge(ridge=1e-6)

esn = reservoir >> readout

# Train and predict
esn = esn.fit(xTrain, yTrain)
yPred = esn.run(xTest)

# Plot
fig, ax = plt.subplots(figsize =(12,4))
ax.plot(yTest[:1000], label = "True")
ax.plot(yPred[:1000], label="Predicted", linestyle="--")
ax.set_title("Lorenz Attractor Prediction (x-axis)")
ax.legend()
# Out:
# Running Model-3:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Model-3:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Model-3: 226it [00:00, 2243.15it/s]
# Running Model-3: 512it [00:00, 2597.09it/s]
# Running Model-3: 772it [00:00, 2016.37it/s]
# Running Model-3: 1027it [00:00, 2193.49it/s]
# Running Model-3: 1371it [00:00, 2573.52it/s]
# Running Model-3: 1672it [00:00, 2701.31it/s]
# Running Model-3: 1950it [00:00, 2709.83it/s]
# Running Model-3: 2227it [00:00, 2514.98it/s]
# Running Model-3: 2576it [00:00, 2791.59it/s]
# Running Model-3: 2985it [00:01, 3166.11it/s]
# Running Model-3: 3410it [00:01, 3476.81it/s]
# Running Model-3: 3821it [00:01, 3662.57it/s]
# Running Model-3: 4258it [00:01, 3870.89it/s]
# Running Model-3: 4660it [00:01, 3912.90it/s]
# Running Model-3: 5054it [00:01, 3835.09it/s]
# Running Model-3: 5480it [00:01, 3948.83it/s]
# Running Model-3: 5881it [00:01, 3960.06it/s]
# Running Model-3: 6279it [00:01, 3918.22it/s]
# Running Model-3: 6680it [00:02, 3944.71it/s]
# Running Model-3: 7096it [00:02, 4006.68it/s]
# Running Model-3: 7498it [00:02, 3785.83it/s]
# Running Model-3: 8000it [00:02, 3305.42it/s]
# Running Model-3: 100%|██████████| 1/1 [00:02<00:00,  2.48s/it]
# Fitting node Ridge-3...
# Running Model-3: 1999it [00:00, 3564.20it/s]
